# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
import matplotlib.pyplot as plt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             5000 non-null object
# Grade            5000 non-null object
# Channel name     5000 non-null object
# Video Uploads    5000 non-null object
# Subscribers      5000 non-null object
# Video views      5000 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
data.size
# Out:
# 30000

# %%
data.shape
# Out:
# (5000, 6)

# %%
data['Video views']
# Out:
# 0       20869786591
# 1       47548839843
# 2        9793305082
# 3       22675948293
# 4       26273668433
# 5       16618094724
# 6       23898730764
# 7       17202609850
# 8       24518098041
# 9        2591830307
# 10       8587520379
# 11      19291034467
# 12       2540099931
# 13       8727783225
# 14      10989179147
# 15       9388600275
# 16      11102158475
# 17       1428274554
# 18       5860444053
# 19      14022189654
# 20       2029279311
# 21      11666909155
# 22       9572788450
# 23        245437560
# 24        349096736
# 25       6585569190
# 26       3437613314
# 27      16395683234
# 28       2754482753
# 29        224608044
#            ...
# 4970      596835119
# 4971      483072980
# 4972      509406756
# 4973      310449113
# 4974      498989227
# 4975       21933876
# 4976      343820279
# 4977      596218763
# 4978       20229141
# 4979      441243129
# 4980     2090085291
# 4981      119924990
# 4982      827849271
# 4983      116728609
# ...

# %%
data[['Video views','Subscribers']] #取多列的方法[]
# Out:
#       Video views Subscribers
# 0     20869786591    18752951
# 1     47548839843    61196302
# 2      9793305082    19238251
# 3     22675948293    31180559
# 4     26273668433    32852346
# 5     16618094724    17149705
# 6     23898730764    11373567
# 7     17202609850    12149206
# 8     24518098041    16082927
# 9      2591830307     2841811
# 10     8587520379    33492951
# 11    19291034467    39409726
# 12     2540099931     7662886
# 13     8727783225    18824912
# 14    10989179147    15899764
# 15     9388600275    11569723
# 16    11102158475    15830098
# 17     1428274554         --
# 18     5860444053    23603062
# 19    14022189654    17687229
# 20     2029279311    11593509
# 21    11666909155    23440427
# 22     9572788450    11347420
# 23      245437560     2137907
# 24      349096736      712562
# 25     6585569190    14469618
# 26     3437613314    16924523
# 27    16395683234    15836366
# 28     2754482753     2902714
# 29      224608044      459906
# ...

# %%
import numpy as np

# %%
Sub_array = np.array(data['Subscribers'])

# %%
View_array = np.array(data['Video views'])

# %%
Sub_array,View_array
# Out:
# (array(['18752951', '61196302', '19238251', ..., '3265735', '32990',
#         '21172'], dtype=object),
#  array([20869786591, 47548839843,  9793305082, ...,   311758426,
#            14563764,    73312511], dtype=int64))

# %%
Sub_array/View_array #Sub_array仍然包含的是str类型
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-0e15cb244318> in <module>()
# ----> 1 Sub_array/View_array
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
#类型转换
data['Subscribers'] = pd.to_numeric(data['Subscribers'])
#不成功，因为有缺失值
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-- "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6dd8bf58a46f> in <module>()
#       1 #类型转换
# ----> 2 data['Subscribers'] = pd.to_numeric(data['Subscribers'])
#
# c:\users\sunriz_\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# ...

# %%
#处理缺失值：由于不清楚规律，直接删除有缺失的数据
data.Subscribers
# Out:
# 0       18752951
# 1       61196302
# 2       19238251
# 3       31180559
# 4       32852346
# 5       17149705
# 6       11373567
# 7       12149206
# 8       16082927
# 9        2841811
# 10      33492951
# 11      39409726
# 12       7662886
# 13      18824912
# 14      15899764
# 15      11569723
# 16      15830098
# 17           --
# 18      23603062
# 19      17687229
# 20      11593509
# 21      23440427
# 22      11347420
# 23       2137907
# 24        712562
# 25      14469618
# 26      16924523
# 27      15836366
# 28       2902714
# 29        459906
#           ...
# 4970      885667
# 4971     2414713
# 4972      673787
# 4973      829870
# 4974     1436546
# 4975      150091
# 4976      229079
# 4977      638404
# 4978      106628
# 4979     1558006
# 4980     6532616
# 4981      158905
# 4982      647435
# 4983      219238
# 4984     2875705
# 4985      820381
# 4986     1123300
# 4987     1536819
# 4988     1349511
# 4989      660742
# 4990         --
# ...

# %%
#或者直接选择忽略
Sub_array = pd.to_numeric(data['Subscribers'],errors='ignore')

# %%
Sub_array = np.array(Sub_array) #但是类型都为object，看来np的转换是找到共同的基类

# %%
Sub_array
# Out:
# array(['18752951', '61196302', '19238251', ..., '3265735', '32990',
#        '21172'], dtype=object)

# %%
#删除缺失行
type(data['Subscribers'])
# Out:
# pandas.core.series.Series

# %%
data = data[ ~ data['Subscribers'].str.contains('--') ]     
#删除，更新方法
#DataFrame 可以用series作为索引，结果为相应的整条数据

# %%
Sub_array = np.array(data['Subscribers'])

# %%
Sub_array#仍不是数字，看来是与建立数据集的设置有关
# Out:
# array(['18752951', '61196302', '19238251', ..., '3265735', '32990',
#        '21172'], dtype=object)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
Sub_array = pd.to_numeric(Sub_array)

# %%
View_array = np.array(data['Video views']) #重新生成View_array，更新维数

# %%
Sub_array,View_array
# Out:
# (array([18752951, 61196302, 19238251, ...,  3265735,    32990,    21172],
#        dtype=int64),
#  array([20869786591, 47548839843,  9793305082, ...,   311758426,
#            14563764,    73312511], dtype=int64))

# %%
div = Sub_array/View_array*100

# %%
div
# Out:
# array([0.08985694, 0.12870199, 0.19644288, ..., 1.04752101, 0.22652111,
#        0.02887911])

# %%
plt.hist(Sub_array,bins=20)
# Out:
# (array([3.601e+03, 5.930e+02, 1.970e+02, 1.030e+02, 5.000e+01, 3.300e+01,
#         8.000e+00, 8.000e+00, 7.000e+00, 5.000e+00, 5.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([3.01000000e+02, 3.30005145e+06, 6.59980190e+06, 9.89955235e+06,
#         1.31993028e+07, 1.64990532e+07, 1.97988037e+07, 2.30985542e+07,
#         2.63983046e+07, 2.96980551e+07, 3.29978055e+07, 3.62975560e+07,
#         3.95973064e+07, 4.28970569e+07, 4.61968073e+07, 4.94965578e+07,
#         5.27963082e+07, 5.60960587e+07, 5.93958091e+07, 6.26955596e+07,
#         6.59953100e+07]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(data['Video views'])
# Out:
# (array([4.423e+03, 1.340e+02, 3.600e+01, 1.300e+01, 3.000e+00, 3.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([7.50000000e+01, 4.75488405e+09, 9.50976803e+09, 1.42646520e+10,
#         1.90195360e+10, 2.37744200e+10, 2.85293039e+10, 3.32841879e+10,
#         3.80390719e+10, 4.27939559e+10, 4.75488398e+10]),
#  <a list of 10 Patch objects>)

# %%
#可见大部分的频道相互差距不大

# %%
import seaborn as sns

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.info
# Out:
# <bound method DataFrame.info of          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# 5         6th  A++                         Movieclips         30243
# 6         7th  A++                         netd müzik          8500
# 7         8th  A++              ABS-CBN Entertainment        100147
# 8         9th  A++                    Ryan ToysReview          1140
# 9        10th  A++                        Zee Marathi         74607
# 10       11th   A+                    5-Minute Crafts          2085
# 11       12th   A+                    Canal KondZilla           822
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# 5         6th  A++                         Movieclips         30243
# 6         7th  A++                         netd müzik          8500
# 7         8th  A++              ABS-CBN Entertainment        100147
# 8         9th  A++                    Ryan ToysReview          1140
# 9        10th  A++                        Zee Marathi         74607
# 10       11th   A+                    5-Minute Crafts          2085
# 11       12th   A+                    Canal KondZilla           822
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4613 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             4613 non-null object
# Grade            4613 non-null object
# Channel name     4613 non-null object
# Video Uploads    4613 non-null object
# Subscribers      4613 non-null object
# Video views      4613 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 252.3+ KB

# %%
data.describe()#只有Video views为数字量
# Out:
#         Video views
# count  4.613000e+03
# mean   1.137713e+09
# std    2.068211e+09
# min    7.500000e+01
# 25%    2.188379e+08
# 50%    5.365047e+08
# 75%    1.194442e+09
# max    4.754884e+10

# %%
data['Subscribers'] = pd.to_numeric(data['Subscribers'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4613 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             4613 non-null object
# Grade            4613 non-null object
# Channel name     4613 non-null object
# Video Uploads    4613 non-null object
# Subscribers      4613 non-null int64
# Video views      4613 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 252.3+ KB

# %%
data = data[ ~data['Video Uploads'].str.contains('--')]

# %%
data['Video Uploads'] = data['Video Uploadso']
# Out:
# c:\users\sunriz_\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data = data.drop(labels='Video Uploadso',axis=1) # axis=1为列，0为行（默认）
#其他参数：index 指定行，columns指定列， inplace = True 对原数据操作，False（默认）返回操作后的数据，不改变原数据
# index,columns ; labels,axis ; 只能用一种组合，等价

# %%
#使用索引将Rank转为数字特征
data['Rank'] = data.index

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4610 entries, 0 to 4999
# Data columns (total 6 columns):
# Rank             4610 non-null int64
# Grade            4610 non-null object
# Channel name     4610 non-null object
# Video Uploads    4610 non-null int64
# Subscribers      4610 non-null int64
# Video views      4610 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 412.1+ KB

# %%
data['Rank'] += 1

# %%
data.head()
# Out:
#    Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0     1  A++                       Zee TV          82757     18752951
# 1     2  A++                     T-Series          12661     61196302
# 2     3  A++   Cocomelon - Nursery Rhymes            373     19238251
# 3     4  A++                    SET India          27323     31180559
# 4     5  A++                          WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
features = ['Rank','Video Uploads','Subscribers','Video views']

# %%
sns.heatmap(data[features].corr(),annot=True,cmap='cubehelix_r')
#主要看Rank与其他量的相关性，发现相关性不大，甚至都为负？

# %%
#总结主要处理：
#1.观察数据：特征，类型
#2.选择处理方法：求相关系数
#3.处理数据：处理缺失数据，数字化
#4.绘图

# %%
#添加特征：div  
div #Sub_array/View_array
# Out:
# array([0.08985694, 0.12870199, 0.19644288, ..., 1.04752101, 0.22652111,
#        0.02887911])

# %%
#维度变化，需重新生成
Sub_array = pd.to_numeric(data['Subscribers'])
View_array = pd.to_numeric(data['Video views'])

# %%
div = Sub_array/View_array

# %%
data['Division'] = div

# %%
features.append('Division')

# %%
sns.heatmap(data[features].corr(),annot=True,cmap='cubehelix_r')
#仍然不相关

# %%
#总结：猜想还有更多评价标准未被收录
